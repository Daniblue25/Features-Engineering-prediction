# %% [markdown]
# # --------Les techniques d'automatisations-----------

# %%
import pandas_profiling

# %%
import ydata_profiling
from ydata_profiling import *
import seaborn as sns

# %%
import pandas as pd

# %%
df = sns.load_dataset('titanic')

# %%
profil = ProfileReport(df, explorative=True, dark_mode=True)
profil.to_file('titanic_output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28352/1787496486.py in <module>
#       1 profil = ProfileReport(df, explorative=True, dark_mode=True)
# ----> 2 profil.to_file('titanic_output.html')
#
# c:\Users\LENOVO\anaconda3\envs\dani_env\lib\site-packages\typeguard\__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# c:\Users\LENOVO\anaconda3\envs\dani_env\lib\site-packages\ydata_profiling\profile_report.py in to_file(self, output_file, silent)
#     345                 create_html_assets(self.config, output_file)
#     346
# ...

# %%
# !pip install dataprep
